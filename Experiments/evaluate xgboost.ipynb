# %%
import pandas as pd
import numpy as np
import os

from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df_ckplus_dataset = pd.read_csv("dataset/ckplus_dataset.csv")

# %%
def read_emotion_features(emotion):
    distance_features = []
    angle_features = []
    with open(f"features/{emotion}.txt", "r") as file:
        for line in file:
            feature = line.strip().split()
            feature = [int(value) for value in feature[0][2:-1].split(",")]
            if len(feature) == 2:
                distance_features.append(feature)
            else:
                angle_features.append(feature)
    return distance_features, angle_features


def load_emotion_features():
    emotions = ["neutral", "anger", "disgust", "fear", "happiness", "sadness", "surprise", 
                "neutral-anger", "neutral-disgust", "neutral-fear", "neutral-happiness", "neutral-sadness", "neutral-surprise",
                ]
    emotion_features = {}
    for emotion in emotions:
        distance_features, angle_features = read_emotion_features(emotion)
        emotion_features[emotion] = (distance_features, angle_features)
    return emotion_features


emotion_features = load_emotion_features()

# %%
def euclidean_distance(a, b):
    return np.sqrt((a[0] - b[0]) ** 2 + (a[1] - b[1]) ** 2)


def smaller_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    ba = a - b
    bc = c - b
    cosine = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    return np.arccos(cosine) * 180 / np.pi


def mid_point(a, b):
    return [(a[0] + b[0]) / 2, (a[1] + b[1]) / 2]


def get_face_width(data):
    point1 = data["landmark_2"].split(" ")
    point1 = [float(point1[0]), float(point1[1])]
    point2 = data["landmark_16"].split(" ")
    point2 = [float(point2[0]), float(point2[1])]
    return euclidean_distance(point1, point2)


def generate_distance_features(data, feature_emotion: str):
    # print("feature_emotion", feature_emotion)
    distance_features_template = emotion_features[feature_emotion][0]

    distance_features = []
    for feature in distance_features_template:
        point1 = data[f"landmark_{feature[0]}"].split(" ")
        point1 = [float(point1[0]), float(point1[1])]
        point2 = data[f"landmark_{feature[1]}"].split(" ")
        point2 = [float(point2[0]), float(point2[1])]

        distance = euclidean_distance(point1, point2)
        distance_features.append(distance)

    if "neutral" in feature_emotion:
        point1 = data["landmark_37"].split(" ")
        point1 = [float(point1[0]), float(point1[1])]
        point2 = data["landmark_46"].split(" ")
        point2 = [float(point2[0]), float(point2[1])]
        point3 = data["landmark_9"].split(" ")
        point3 = [float(point3[0]), float(point3[1])]

        distance = euclidean_distance(mid_point(point1, point2), point3)
        distance_features.append(distance)

    distance_features = np.array(distance_features)
    distance_features = distance_features / get_face_width(data)

    return distance_features


def generate_angle_features(data, feature_emotion):
    angle_features_template = emotion_features[feature_emotion][1]

    angle_features = []
    for feature in angle_features_template:
        point1 = data[f"landmark_{feature[0]}"].split(" ")
        point1 = [float(point1[0]), float(point1[1])]
        point2 = data[f"landmark_{feature[1]}"].split(" ")
        point2 = [float(point2[0]), float(point2[1])]
        point3 = data[f"landmark_{feature[2]}"].split(" ")
        point3 = [float(point3[0]), float(point3[1])]

        angle = smaller_angle(point1, point2, point3)
        angle_features.append(angle)

    angle_features = np.array(angle_features)
    angle_features = angle_features / 180

    return angle_features

# %%
def generate_features(data, feature_emotion, feature_type):
    features = np.array([])

    if feature_type == "distance" or feature_type == "both":
        distance_features = generate_distance_features(data, feature_emotion)
        features = np.concatenate((features, distance_features))

    if feature_type == "angle" or feature_type == "both":
        angle_features = generate_angle_features(data, feature_emotion)
        features = np.concatenate((features, angle_features))
        
        
    # print(feature_emotion, features.shape)

    return features


def generate_features_multiple(data, feature_emotions, feature_type):
    all_features = np.array([])
    
    for feature_emotion in feature_emotions:
        features = generate_features(data, feature_emotion, feature_type)
        all_features = np.concatenate((all_features, features))
        
    return all_features


def get_features_from_df(df, feature_emotions, feature_type):
    features = []
    for index, row in df.iterrows():
        features.append(generate_features_multiple(row, feature_emotions, feature_type))

    features = np.array(features)
    
    return features


def get_classes_from_df(df):
    classes = []
    for index, row in df.iterrows():
        classes.append(row["subject_id"])
    return np.array(classes)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.linear_model import (
    LogisticRegression,
    Perceptron,
    RidgeClassifier,
    SGDClassifier,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import (
    AdaBoostClassifier,
    BaggingClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,
    ExtraTreesClassifier,
)
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

# %%
def get_model(model_type, seed):
    if model_type == "LinearDiscriminantAnalysis":
        return LinearDiscriminantAnalysis()

    if model_type == "QuadraticDiscriminantAnalysis":
        # QuadraticDiscriminantAnalysis
        return QuadraticDiscriminantAnalysis()

    if model_type == "LinearSVC":
        # LinearSVC
        return LinearSVC(random_state=seed)

    if model_type == "NuSVC":
        # NuSVC
        return NuSVC(random_state=seed)

    if model_type == "SVC":
        # SVC
        return SVC(random_state=seed)

    if model_type == "DecisionTreeClassifier":
        # DecisionTreeClassifier
        return DecisionTreeClassifier(random_state=seed)

    if model_type == "ExtraTreeClassifier":
        # ExtraTreeClassifier
        return ExtraTreeClassifier(random_state=seed)

    if model_type == "LogisticRegression":
        # LogisticRegression
        return LogisticRegression(random_state=seed)

    if model_type == "Perceptron":
        return Perceptron(random_state=seed)

    if model_type == "RidgeClassifier":
        return RidgeClassifier(random_state=seed)

    if model_type == "SGDClassifier":
        return SGDClassifier(random_state=seed)

    if model_type == "KNeighborsClassifier":
        return KNeighborsClassifier()

    if model_type == "GaussianProcessClassifier":
        return GaussianProcessClassifier(random_state=seed)

    if model_type == "GaussianNB":
        return GaussianNB()

    if model_type == "AdaBoostClassifier":
        return AdaBoostClassifier(random_state=seed)

    if model_type == "BaggingClassifier":
        return BaggingClassifier(random_state=seed)

    if model_type == "RandomForestClassifier":
        return RandomForestClassifier(random_state=seed)

    if model_type == "GradientBoostingClassifier":
        return GradientBoostingClassifier(random_state=seed)

    if model_type == "ExtraTreesClassifier":
        return ExtraTreesClassifier(random_state=seed)
    
    if model_type == "MLPClassifier":
        return MLPClassifier(random_state=seed, max_iter=1000)
    
    # xgboost
    if model_type == "XGBClassifier":
        return XGBClassifier(random_state=seed)

    raise ValueError("Invalid model type")


def train_model(model, X_train, y_train):
    print(X_train.shape, y_train.shape)
    
    model.fit(X_train, y_train)
    return model


def test_model(model, X_test, y_test):
    return model.score(X_test, y_test)

# %%
def get_subject_session_data(subject_id, session_id):
    return df_ckplus_dataset[
        (df_ckplus_dataset["subject_id"] == subject_id)
        & (df_ckplus_dataset["session_id"] == session_id)
    ]


def get_subjects(emotion, no_of_subjects):
    print(f"Reading subjects for {emotion}... [no_of_subjects={no_of_subjects}]")
    df_subjects = pd.read_csv(f"dataset/{emotion}_filtered.csv")
    if no_of_subjects is not None:
        df_subjects = df_subjects.head(no_of_subjects)
    assert no_of_subjects is None or len(df_subjects) == no_of_subjects
    df_subjects = df_subjects[["subject_id", "session_id"]]
    
    return df_subjects

# %%
def generate_train_test_data(emotion, no_of_subjects, seed=42):
    subjects = get_subjects(emotion=emotion, no_of_subjects=no_of_subjects)

    df_neutral_train = pd.DataFrame()
    df_neutral_test = pd.DataFrame()
    df_emotion_train = pd.DataFrame()
    df_emotion_test = pd.DataFrame()

    for index, row in subjects.iterrows():
        subject_id = row["subject_id"]
        session_id = row["session_id"]
        subject_data = get_subject_session_data(subject_id, session_id)

        neutral_data = subject_data.head(len(subject_data) // 2)
        emotion_data = subject_data.tail(len(subject_data) // 2)
        
        neutral_data = neutral_data.sample(n=3, random_state=seed)
        emotion_data = emotion_data.sample(n=3, random_state=seed)

        neutral_train = neutral_data.head(2)
        neutral_test = neutral_data.tail(1)
        
        emotion_train = emotion_data.head(2)
        emotion_test = emotion_data.tail(1)
        
        df_neutral_train = pd.concat([df_neutral_train, neutral_train])
        df_neutral_test = pd.concat([df_neutral_test, neutral_test])
        
        df_emotion_train = pd.concat([df_emotion_train, emotion_train])
        df_emotion_test = pd.concat([df_emotion_test, emotion_test])
        
        # df = pd.concat([df_neutral_train, df_neutral_test, df_emotion_train, df_emotion_test])
        # unique_subject_ids = df['subject_id'].unique()
        # id_to_label = {subject_id: idx for idx, subject_id in enumerate(unique_subject_ids)}
        # label_to_id = {idx: subject_id for idx, subject_id in enumerate(unique_subject_ids)}
        
        
        # df_neutral_train['subject_label'] = df_neutral_train['subject_id'].map(id_to_label)
        # df_neutral_test['subject_label'] = df_neutral_test['subject_id'].map(id_to_label)

        # df_emotion_train['subject_label'] = df_emotion_train['subject_id'].map(id_to_label)
        # df_emotion_test['subject_label'] = df_emotion_test['subject_id'].map(id_to_label)


        
    return df_neutral_train, df_neutral_test, df_emotion_train, df_emotion_test

# %%
def evaluate_performance(df_train, df_test, feature_emotions: list, feature_type, model_type, seed):
    X_train = get_features_from_df(df_train, feature_emotions, feature_type)
    y_train = get_classes_from_df(df_train)

    X_test = get_features_from_df(df_test, feature_emotions, feature_type)
    y_test = get_classes_from_df(df_test)
    
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    # 
    encoder = LabelEncoder()
    y_train = encoder.fit_transform(y_train)
    y_test = encoder.transform(y_test) 
    
    
    model = get_model(model_type, seed)
    model = train_model(model, X_train, y_train)

    return test_model(model, X_test, y_test)

# %%
def run_test(
    emotion, 
    model_type,
    training_set,
    test_set,
    feature,
    no_of_tests, 
    seed,
    no_of_subjects=None
):

    print(f"{emotion}: {training_set}-{test_set} with {feature} using {model_type}")

    np.random.seed(seed)
    seeds = np.random.randint(0, 1000, no_of_tests)

    scores = np.array([])
    for test in range(no_of_tests):
        print(f"Running test #{test+1}/{no_of_tests}")

        df_neutral_train, df_neutral_test, df_emotion_train, df_emotion_test = (
            generate_train_test_data(emotion=emotion, seed=seeds[test], no_of_subjects=no_of_subjects)
        )
        
        df_combined_train = pd.concat([df_neutral_train, df_emotion_train])
        df_combined_test = pd.concat([df_neutral_test, df_emotion_test])

        df_train = None
        if training_set == "neutral":
            df_train = df_neutral_train
        elif training_set == f"{emotion}":
            df_train = df_emotion_train
        elif training_set == f"neutral_{emotion}":
            df_train = df_combined_train
        assert df_train is not None

        df_test = None
        if test_set == "neutral":
            df_test = df_neutral_test
        elif test_set == f"{emotion}":
            df_test = df_emotion_test
        elif test_set == f"neutral_{emotion}":
            df_test = df_combined_test
        assert df_test is not None

        feature_emotions = None
        if feature == "neutral":
            feature_emotions = ["neutral"]
        elif feature == f"{emotion}":
            feature_emotions = [emotion]
        elif feature == f"neutral_{emotion}":
            # feature_emotions = ["neutral", emotion]
            feature_emotions = [f"neutral-{emotion}"]
        assert feature_emotions is not None

        score = evaluate_performance(
            df_train=df_train,
            df_test=df_test,
            feature_emotions=feature_emotions,
            feature_type="distance",
            model_type=model_type,
            seed=seeds[test],
        )

        print("Score: ", score * 100)
        scores = np.append(scores, score)

    result = {
        "training_set": training_set,
        "test_set": test_set,
        "feature_set": feature,
        "feature_type": "distance",
        "model_type": model_type,
        "accuracy": 100 * scores.mean(),
    }

    return result

# %%
# TODO: change emotions
emotions = [
    "anger",
    "disgust",
    "fear",
    "happiness",
    "sadness",
    "surprise",
]

models = [
    # "LinearDiscriminantAnalysis",
    # "LinearSVC",
    # "SVC",
    # "DecisionTreeClassifier",
    # "ExtraTreeClassifier",
    # "LogisticRegression",
    # "Perceptron",
    # "KNeighborsClassifier",
    # "GaussianProcessClassifier",
    # "GaussianNB",
    # "BaggingClassifier",
    # "RandomForestClassifier",
    # "GradientBoostingClassifier",
    # "ExtraTreesClassifier",
    "XGBClassifier",
]

neutral = "neutral"

no_of_data = None
no_of_tests = 25
seed = 73

# %%
for emotion in emotions:
    df_results = pd.DataFrame(
        columns=["training_set", "test_set", "feature_set", "feature_type", "model_type", "accuracy"]
    )

    for model_type in models:

#         # neutral-neutral with neutral
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=neutral,
        #     test_set=neutral,
        #     feature=neutral,
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # neutral-neutral with emotion
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=neutral,
        #     test_set=neutral,
        #     feature=emotion,
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # neutral-neutral with both
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=neutral,
        #     test_set=neutral,
        #     feature=f"{neutral}_{emotion}",
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()

#         # neutral-emotion with neutral
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=neutral,
        #     test_set=emotion,
        #     feature=neutral,
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # neutral-emotion with emotion
#         result = run_test(
#             emotion=emotion,
#             model_type=model_type,
#             training_set=neutral,
#             test_set=emotion,
#             feature=emotion,
#             no_of_tests=no_of_tests,
#             seed=seed,
#         )
#         df_results.loc[len(df_results)] = result
#         print(df_results)
#         print()
# 
#         # neutral-emotion with both
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=neutral,
        #     test_set=emotion,
        #     feature=f"{neutral}_{emotion}",
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # emotion-neutral with neutral
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=emotion,
        #     test_set=neutral,
        #     feature=neutral,
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # emotion-neutral with emotion
#         result = run_test(
#             emotion=emotion,
#             model_type=model_type,
#             training_set=emotion,
#             test_set=neutral,
#             feature=emotion,
#             no_of_tests=no_of_tests,
#             seed=seed,
#         )
#         df_results.loc[len(df_results)] = result
#         print(df_results)
#         print()
# 
#         # emotion-neutral with both
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=emotion,
        #     test_set=neutral,
        #     feature=f"{neutral}_{emotion}",
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()
# 
#         # emotion-emotion with neutral
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=emotion,
        #     test_set=emotion,
        #     feature=neutral,
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()

#         # emotion-emotion with emotion
#         result = run_test(
#             emotion=emotion,
#             model_type=model_type,
#             training_set=emotion,
#             test_set=emotion,
#             feature=emotion,
#             no_of_tests=no_of_tests,
#             seed=seed,
#         )
#         df_results.loc[len(df_results)] = result
#         print(df_results)
#         print()
# 
#         # emotion-emotion with both
        # result = run_test(
        #     emotion=emotion,
        #     model_type=model_type,
        #     training_set=emotion,
        #     test_set=emotion,
        #     feature=f"{neutral}_{emotion}",
        #     no_of_tests=no_of_tests,
        #     seed=seed,
        # )
        # df_results.loc[len(df_results)] = result
        # print(df_results)
        # print()

        # both-both with neutral
        result = run_test(
            emotion=emotion,
            model_type=model_type,
            training_set=f"{neutral}_{emotion}",
            test_set=f"{neutral}_{emotion}",
            feature=neutral,
            no_of_tests=no_of_tests,
            seed=seed,
        )
        df_results.loc[len(df_results)] = result
        print(df_results)
        print()

        # both-both with emotion
        result = run_test(
            emotion=emotion,
            model_type=model_type,
            training_set=f"{neutral}_{emotion}",
            test_set=f"{neutral}_{emotion}",
            feature=emotion,
            no_of_tests=no_of_tests,
            seed=seed,
        )
        df_results.loc[len(df_results)] = result
        print(df_results)
        print()

        # both-both with both
        result = run_test(
            emotion=emotion,
            model_type=model_type,
            training_set=f"{neutral}_{emotion}",
            test_set=f"{neutral}_{emotion}",
            feature=f"{neutral}_{emotion}",
            no_of_tests=no_of_tests,
            seed=seed,
        )
        df_results.loc[len(df_results)] = result
        print(df_results)
        print()
        
        
        df_results.to_csv(f"results/{emotion}_temp.csv")
        
    
    df_results.to_csv(f"results/{emotion}.csv")
# Out:
# anger: neutral_anger-neutral_anger with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  79.3103448275862
# Running test #2/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  84.48275862068965
# Running test #3/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  82.75862068965517
# Running test #4/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  82.75862068965517
# Running test #5/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  88.79310344827587
# Running test #6/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  99.13793103448276
# Running test #7/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  92.24137931034483
# Running test #8/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  93.10344827586206
# Running test #9/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  91.37931034482759
# Running test #10/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  90.51724137931035
# Running test #11/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  89.65517241379311
# Running test #12/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  93.96551724137932
# Running test #13/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  86.20689655172413
# Running test #14/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  82.75862068965517
# Running test #15/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  81.89655172413794
# Running test #16/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  89.65517241379311
# Running test #17/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  81.03448275862068
# Running test #18/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  91.37931034482759
# Running test #19/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  89.65517241379311
# Running test #20/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  91.37931034482759
# Running test #21/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  82.75862068965517
# Running test #22/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  81.89655172413794
# Running test #23/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  81.89655172413794
# Running test #24/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  78.44827586206897
# Running test #25/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 9) (232,)
# Score:  81.89655172413794
#     training_set       test_set feature_set feature_type     model_type  \
# 0  neutral_anger  neutral_anger     neutral     distance  XGBClassifier
#
#     accuracy
# 0  86.758621
#
# anger: neutral_anger-neutral_anger with anger using XGBClassifier
# Running test #1/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  80.17241379310344
# Running test #2/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  78.44827586206897
# Running test #3/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  80.17241379310344
# Running test #4/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  81.89655172413794
# Running test #5/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  80.17241379310344
# Running test #6/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  91.37931034482759
# Running test #7/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  85.34482758620689
# Running test #8/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  84.48275862068965
# Running test #9/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  87.06896551724138
# Running test #10/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  90.51724137931035
# Running test #11/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  81.03448275862068
# Running test #12/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  84.48275862068965
# Running test #13/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  84.48275862068965
# Running test #14/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  79.3103448275862
# Running test #15/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  78.44827586206897
# Running test #16/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  78.44827586206897
# Running test #17/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  75.86206896551724
# Running test #18/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  84.48275862068965
# Running test #19/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  80.17241379310344
# Running test #20/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  85.34482758620689
# Running test #21/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  79.3103448275862
# Running test #22/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  81.89655172413794
# Running test #23/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  76.72413793103449
# Running test #24/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  78.44827586206897
# Running test #25/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 12) (232,)
# Score:  81.89655172413794
#     training_set       test_set feature_set feature_type     model_type  \
# 0  neutral_anger  neutral_anger     neutral     distance  XGBClassifier
# 1  neutral_anger  neutral_anger       anger     distance  XGBClassifier
#
#     accuracy
# 0  86.758621
# 1  82.000000
#
# anger: neutral_anger-neutral_anger with neutral_anger using XGBClassifier
# Running test #1/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  82.75862068965517
# Running test #2/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  82.75862068965517
# Running test #3/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  86.20689655172413
# Running test #4/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  87.93103448275862
# Running test #5/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  92.24137931034483
# Running test #6/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  96.55172413793103
# Running test #7/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  94.82758620689656
# Running test #8/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  92.24137931034483
# Running test #9/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  91.37931034482759
# Running test #10/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  93.10344827586206
# Running test #11/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  89.65517241379311
# Running test #12/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  91.37931034482759
# Running test #13/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  90.51724137931035
# Running test #14/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  86.20689655172413
# Running test #15/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  81.03448275862068
# Running test #16/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  86.20689655172413
# Running test #17/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  83.62068965517241
# Running test #18/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  88.79310344827587
# Running test #19/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  87.93103448275862
# Running test #20/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  89.65517241379311
# Running test #21/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  86.20689655172413
# Running test #22/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  84.48275862068965
# Running test #23/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  83.62068965517241
# Running test #24/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  81.89655172413794
# Running test #25/25
# Reading subjects for anger... [no_of_subjects=None]
# (232, 19) (232,)
# Score:  85.34482758620689
#     training_set       test_set    feature_set feature_type     model_type  \
# 0  neutral_anger  neutral_anger        neutral     distance  XGBClassifier
# 1  neutral_anger  neutral_anger          anger     distance  XGBClassifier
# 2  neutral_anger  neutral_anger  neutral_anger     distance  XGBClassifier
#
#     accuracy
# 0  86.758621
# 1  82.000000
# 2  87.862069
#
# disgust: neutral_disgust-neutral_disgust with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  83.33333333333334
# Running test #2/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  86.11111111111111
# Running test #3/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  83.33333333333334
# Running test #4/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  79.86111111111111
# Running test #5/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  83.33333333333334
# Running test #6/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  95.13888888888889
# Running test #7/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  90.97222222222221
# Running test #8/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  88.88888888888889
# Running test #9/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  94.44444444444444
# Running test #10/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  87.5
# Running test #11/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  82.63888888888889
# Running test #12/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  95.83333333333334
# Running test #13/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  83.33333333333334
# Running test #14/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  80.55555555555556
# Running test #15/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  86.80555555555556
# Running test #16/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  81.94444444444444
# Running test #17/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  83.33333333333334
# Running test #18/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  88.19444444444444
# Running test #19/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  89.58333333333334
# Running test #20/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  86.80555555555556
# Running test #21/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  80.55555555555556
# Running test #22/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  92.36111111111111
# Running test #23/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  84.72222222222221
# Running test #24/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  82.63888888888889
# Running test #25/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 9) (288,)
# Score:  84.02777777777779
#       training_set         test_set feature_set feature_type     model_type  \
# 0  neutral_disgust  neutral_disgust     neutral     distance  XGBClassifier
#
#    accuracy
# 0     86.25
#
# disgust: neutral_disgust-neutral_disgust with disgust using XGBClassifier
# Running test #1/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  77.08333333333334
# Running test #2/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.25
# Running test #3/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  84.72222222222221
# Running test #4/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  82.63888888888889
# Running test #5/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  86.11111111111111
# Running test #6/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  92.36111111111111
# Running test #7/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  88.88888888888889
# Running test #8/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  93.05555555555556
# Running test #9/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  92.36111111111111
# Running test #10/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  90.27777777777779
# Running test #11/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.94444444444444
# Running test #12/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  96.52777777777779
# Running test #13/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  88.19444444444444
# Running test #14/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.94444444444444
# Running test #15/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  79.16666666666666
# Running test #16/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  84.02777777777779
# Running test #17/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  75.0
# Running test #18/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  90.27777777777779
# Running test #19/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  92.36111111111111
# Running test #20/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  83.33333333333334
# Running test #21/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.94444444444444
# Running test #22/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  92.36111111111111
# Running test #23/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.25
# Running test #24/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  78.47222222222221
# Running test #25/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 11) (288,)
# Score:  81.94444444444444
#       training_set         test_set feature_set feature_type     model_type  \
# 0  neutral_disgust  neutral_disgust     neutral     distance  XGBClassifier
# 1  neutral_disgust  neutral_disgust     disgust     distance  XGBClassifier
#
#    accuracy
# 0     86.25
# 1     85.50
#
# disgust: neutral_disgust-neutral_disgust with neutral_disgust using XGBClassifier
# Running test #1/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  86.80555555555556
# Running test #2/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.97222222222221
# Running test #3/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  88.88888888888889
# Running test #4/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  84.72222222222221
# Running test #5/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  91.66666666666666
# Running test #6/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  95.13888888888889
# Running test #7/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  93.05555555555556
# Running test #8/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  93.75
# Running test #9/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  95.83333333333334
# Running test #10/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  91.66666666666666
# Running test #11/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.27777777777779
# Running test #12/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  97.91666666666666
# Running test #13/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.97222222222221
# Running test #14/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.27777777777779
# Running test #15/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  88.88888888888889
# Running test #16/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  86.80555555555556
# Running test #17/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  85.41666666666666
# Running test #18/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  93.05555555555556
# Running test #19/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  97.22222222222221
# Running test #20/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.97222222222221
# Running test #21/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.27777777777779
# Running test #22/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  95.13888888888889
# Running test #23/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  90.27777777777779
# Running test #24/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  88.88888888888889
# Running test #25/25
# Reading subjects for disgust... [no_of_subjects=None]
# (288, 18) (288,)
# Score:  92.36111111111111
#       training_set         test_set      feature_set feature_type  \
# 0  neutral_disgust  neutral_disgust          neutral     distance
# 1  neutral_disgust  neutral_disgust          disgust     distance
# 2  neutral_disgust  neutral_disgust  neutral_disgust     distance
#
#       model_type  accuracy
# 0  XGBClassifier     86.25
# 1  XGBClassifier     85.50
# 2  XGBClassifier     91.25
#
# fear: neutral_fear-neutral_fear with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  83.63636363636363
# Running test #2/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  81.81818181818183
# Running test #3/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  90.0
# Running test #4/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #5/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  91.81818181818183
# Running test #6/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  91.81818181818183
# Running test #7/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  92.72727272727272
# Running test #8/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  89.0909090909091
# Running test #9/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  84.54545454545455
# Running test #10/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  97.27272727272728
# Running test #11/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #12/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  90.9090909090909
# Running test #13/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  87.27272727272727
# Running test #14/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  86.36363636363636
# Running test #15/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  86.36363636363636
# Running test #16/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  86.36363636363636
# Running test #17/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #18/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #19/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  89.0909090909091
# Running test #20/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #21/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  86.36363636363636
# Running test #22/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  91.81818181818183
# Running test #23/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  85.45454545454545
# Running test #24/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  83.63636363636363
# Running test #25/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 9) (220,)
# Score:  86.36363636363636
#    training_set      test_set feature_set feature_type     model_type  \
# 0  neutral_fear  neutral_fear     neutral     distance  XGBClassifier
#
#    accuracy
# 0      87.6
#
# fear: neutral_fear-neutral_fear with fear using XGBClassifier
# Running test #1/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  86.36363636363636
# Running test #2/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  76.36363636363637
# Running test #3/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  91.81818181818183
# Running test #4/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  89.0909090909091
# Running test #5/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  91.81818181818183
# Running test #6/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  86.36363636363636
# Running test #7/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  88.18181818181819
# Running test #8/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  91.81818181818183
# Running test #9/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  82.72727272727273
# Running test #10/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  94.54545454545455
# Running test #11/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  90.0
# Running test #12/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  90.9090909090909
# Running test #13/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  87.27272727272727
# Running test #14/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  86.36363636363636
# Running test #15/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  81.81818181818183
# Running test #16/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  85.45454545454545
# Running test #17/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  79.0909090909091
# Running test #18/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  88.18181818181819
# Running test #19/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  89.0909090909091
# Running test #20/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  85.45454545454545
# Running test #21/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  86.36363636363636
# Running test #22/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  85.45454545454545
# Running test #23/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  85.45454545454545
# Running test #24/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  75.45454545454545
# Running test #25/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 12) (220,)
# Score:  84.54545454545455
#    training_set      test_set feature_set feature_type     model_type  \
# 0  neutral_fear  neutral_fear     neutral     distance  XGBClassifier
# 1  neutral_fear  neutral_fear        fear     distance  XGBClassifier
#
#    accuracy
# 0      87.6
# 1      86.4
#
# fear: neutral_fear-neutral_fear with neutral_fear using XGBClassifier
# Running test #1/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.0
# Running test #2/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  85.45454545454545
# Running test #3/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  95.45454545454545
# Running test #4/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  91.81818181818183
# Running test #5/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  93.63636363636364
# Running test #6/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.9090909090909
# Running test #7/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  97.27272727272728
# Running test #8/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  97.27272727272728
# Running test #9/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.9090909090909
# Running test #10/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  99.0909090909091
# Running test #11/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  92.72727272727272
# Running test #12/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  94.54545454545455
# Running test #13/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.0
# Running test #14/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  91.81818181818183
# Running test #15/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.9090909090909
# Running test #16/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.9090909090909
# Running test #17/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  86.36363636363636
# Running test #18/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  94.54545454545455
# Running test #19/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  93.63636363636364
# Running test #20/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  90.9090909090909
# Running test #21/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  91.81818181818183
# Running test #22/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  93.63636363636364
# Running test #23/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  91.81818181818183
# Running test #24/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  85.45454545454545
# Running test #25/25
# Reading subjects for fear... [no_of_subjects=None]
# (220, 20) (220,)
# Score:  92.72727272727272
#    training_set      test_set   feature_set feature_type     model_type  \
# 0  neutral_fear  neutral_fear       neutral     distance  XGBClassifier
# 1  neutral_fear  neutral_fear          fear     distance  XGBClassifier
# 2  neutral_fear  neutral_fear  neutral_fear     distance  XGBClassifier
#
#     accuracy
# 0  87.600000
# 1  86.400000
# 2  92.145455
#
# happiness: neutral_happiness-neutral_happiness with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  89.44444444444444
# Running test #2/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  85.55555555555556
# Running test #3/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  88.88888888888889
# Running test #4/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  88.88888888888889
# Running test #5/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  90.0
# Running test #6/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  95.55555555555556
# Running test #7/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.11111111111111
# Running test #8/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.11111111111111
# Running test #9/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.11111111111111
# Running test #10/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  95.55555555555556
# Running test #11/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  89.44444444444444
# Running test #12/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  94.44444444444444
# Running test #13/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.66666666666666
# Running test #14/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  87.22222222222223
# Running test #15/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  83.88888888888889
# Running test #16/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  87.77777777777777
# Running test #17/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  75.0
# Running test #18/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.11111111111111
# Running test #19/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  87.77777777777777
# Running test #20/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  91.66666666666666
# Running test #21/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  87.22222222222223
# Running test #22/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  85.55555555555556
# Running test #23/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  86.11111111111111
# Running test #24/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  83.88888888888889
# Running test #25/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 9) (360,)
# Score:  84.44444444444444
#         training_set           test_set feature_set feature_type  \
# 0  neutral_happiness  neutral_happiness     neutral     distance
#
#       model_type   accuracy
# 0  XGBClassifier  88.577778
#
# happiness: neutral_happiness-neutral_happiness with happiness using XGBClassifier
# Running test #1/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  91.11111111111111
# Running test #2/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  83.88888888888889
# Running test #3/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  85.55555555555556
# Running test #4/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  87.77777777777777
# Running test #5/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  91.11111111111111
# Running test #6/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  92.22222222222223
# Running test #7/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  90.0
# Running test #8/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  91.66666666666666
# Running test #9/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  91.11111111111111
# Running test #10/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  97.22222222222221
# Running test #11/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  89.44444444444444
# Running test #12/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  92.22222222222223
# Running test #13/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  92.77777777777779
# Running test #14/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  89.44444444444444
# Running test #15/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  80.0
# Running test #16/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  87.77777777777777
# Running test #17/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  82.77777777777777
# Running test #18/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  92.77777777777779
# Running test #19/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  92.22222222222223
# Running test #20/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  90.55555555555556
# Running test #21/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  89.44444444444444
# Running test #22/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  87.22222222222223
# Running test #23/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  90.0
# Running test #24/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  79.44444444444444
# Running test #25/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 12) (360,)
# Score:  85.0
#         training_set           test_set feature_set feature_type  \
# 0  neutral_happiness  neutral_happiness     neutral     distance
# 1  neutral_happiness  neutral_happiness   happiness     distance
#
#       model_type   accuracy
# 0  XGBClassifier  88.577778
# 1  XGBClassifier  88.911111
#
# happiness: neutral_happiness-neutral_happiness with neutral_happiness using XGBClassifier
# Running test #1/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  98.88888888888889
# Running test #2/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  89.44444444444444
# Running test #3/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.55555555555556
# Running test #4/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  94.44444444444444
# Running test #5/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  97.22222222222221
# Running test #6/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  96.11111111111111
# Running test #7/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  94.44444444444444
# Running test #8/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.0
# Running test #9/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  96.11111111111111
# Running test #10/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  98.33333333333333
# Running test #11/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  96.66666666666667
# Running test #12/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.55555555555556
# Running test #13/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.55555555555556
# Running test #14/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.0
# Running test #15/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  87.77777777777777
# Running test #16/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  92.77777777777779
# Running test #17/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  91.11111111111111
# Running test #18/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  97.77777777777777
# Running test #19/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  96.66666666666667
# Running test #20/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.0
# Running test #21/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.0
# Running test #22/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  91.11111111111111
# Running test #23/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  95.55555555555556
# Running test #24/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  89.44444444444444
# Running test #25/25
# Reading subjects for happiness... [no_of_subjects=None]
# (360, 21) (360,)
# Score:  92.77777777777779
#         training_set           test_set        feature_set feature_type  \
# 0  neutral_happiness  neutral_happiness            neutral     distance
# 1  neutral_happiness  neutral_happiness          happiness     distance
# 2  neutral_happiness  neutral_happiness  neutral_happiness     distance
#
#       model_type   accuracy
# 0  XGBClassifier  88.577778
# 1  XGBClassifier  88.911111
# 2  XGBClassifier  94.533333
#
# sadness: neutral_sadness-neutral_sadness with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  86.56716417910447
# Running test #2/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  82.08955223880598
# Running test #3/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  89.55223880597015
# Running test #4/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  87.31343283582089
# Running test #5/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  88.05970149253731
# Running test #6/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  91.7910447761194
# Running test #7/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  91.7910447761194
# Running test #8/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  91.04477611940298
# Running test #9/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  89.55223880597015
# Running test #10/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  95.52238805970148
# Running test #11/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  90.29850746268657
# Running test #12/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  94.02985074626866
# Running test #13/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  88.05970149253731
# Running test #14/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  92.53731343283582
# Running test #15/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  85.07462686567165
# Running test #16/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  88.05970149253731
# Running test #17/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  82.83582089552239
# Running test #18/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  88.80597014925374
# Running test #19/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  91.7910447761194
# Running test #20/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  91.7910447761194
# Running test #21/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  92.53731343283582
# Running test #22/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  90.29850746268657
# Running test #23/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  85.07462686567165
# Running test #24/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  85.82089552238806
# Running test #25/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 9) (268,)
# Score:  87.31343283582089
#       training_set         test_set feature_set feature_type     model_type  \
# 0  neutral_sadness  neutral_sadness     neutral     distance  XGBClassifier
#
#     accuracy
# 0  89.104478
#
# sadness: neutral_sadness-neutral_sadness with sadness using XGBClassifier
# Running test #1/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  90.29850746268657
# Running test #2/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  89.55223880597015
# Running test #3/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  88.80597014925374
# Running test #4/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  88.05970149253731
# Running test #5/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  88.05970149253731
# Running test #6/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  91.7910447761194
# Running test #7/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  93.28358208955224
# Running test #8/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  93.28358208955224
# Running test #9/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  91.04477611940298
# Running test #10/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  95.52238805970148
# Running test #11/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  88.80597014925374
# Running test #12/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  94.77611940298507
# Running test #13/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  86.56716417910447
# Running test #14/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  89.55223880597015
# Running test #15/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  84.32835820895522
# Running test #16/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  85.82089552238806
# Running test #17/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  82.83582089552239
# Running test #18/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  86.56716417910447
# Running test #19/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  91.04477611940298
# Running test #20/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  91.7910447761194
# Running test #21/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  89.55223880597015
# Running test #22/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  87.31343283582089
# Running test #23/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  86.56716417910447
# Running test #24/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  88.05970149253731
# Running test #25/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 11) (268,)
# Score:  83.5820895522388
#       training_set         test_set feature_set feature_type     model_type  \
# 0  neutral_sadness  neutral_sadness     neutral     distance  XGBClassifier
# 1  neutral_sadness  neutral_sadness     sadness     distance  XGBClassifier
#
#     accuracy
# 0  89.104478
# 1  89.074627
#
# sadness: neutral_sadness-neutral_sadness with neutral_sadness using XGBClassifier
# Running test #1/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  93.28358208955224
# Running test #2/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  87.31343283582089
# Running test #3/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  94.77611940298507
# Running test #4/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  91.7910447761194
# Running test #5/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  93.28358208955224
# Running test #6/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  95.52238805970148
# Running test #7/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  94.02985074626866
# Running test #8/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  94.77611940298507
# Running test #9/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  97.01492537313433
# Running test #10/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  98.50746268656717
# Running test #11/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  92.53731343283582
# Running test #12/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  94.02985074626866
# Running test #13/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  90.29850746268657
# Running test #14/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  92.53731343283582
# Running test #15/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  87.31343283582089
# Running test #16/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  91.04477611940298
# Running test #17/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  88.80597014925374
# Running test #18/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  93.28358208955224
# Running test #19/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  94.77611940298507
# Running test #20/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  95.52238805970148
# Running test #21/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  92.53731343283582
# Running test #22/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  91.7910447761194
# Running test #23/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  88.80597014925374
# Running test #24/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  88.05970149253731
# Running test #25/25
# Reading subjects for sadness... [no_of_subjects=None]
# (268, 19) (268,)
# Score:  93.28358208955224
#       training_set         test_set      feature_set feature_type  \
# 0  neutral_sadness  neutral_sadness          neutral     distance
# 1  neutral_sadness  neutral_sadness          sadness     distance
# 2  neutral_sadness  neutral_sadness  neutral_sadness     distance
#
#       model_type   accuracy
# 0  XGBClassifier  89.104478
# 1  XGBClassifier  89.074627
# 2  XGBClassifier  92.597015
#
# surprise: neutral_surprise-neutral_surprise with neutral using XGBClassifier
# Running test #1/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  82.6086956521739
# Running test #2/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  78.80434782608695
# Running test #3/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  80.97826086956522
# Running test #4/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  76.63043478260869
# Running test #5/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  81.52173913043478
# Running test #6/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  84.23913043478261
# Running test #7/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  82.6086956521739
# Running test #8/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  85.32608695652173
# Running test #9/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  86.95652173913044
# Running test #10/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  87.5
# Running test #11/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  77.71739130434783
# Running test #12/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  89.13043478260869
# Running test #13/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  81.52173913043478
# Running test #14/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  79.8913043478261
# Running test #15/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  78.80434782608695
# Running test #16/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  78.80434782608695
# Running test #17/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  70.65217391304348
# Running test #18/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  82.6086956521739
# Running test #19/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  86.41304347826086
# Running test #20/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  79.8913043478261
# Running test #21/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  79.8913043478261
# Running test #22/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  86.41304347826086
# Running test #23/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  78.26086956521739
# Running test #24/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  69.02173913043478
# Running test #25/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 9) (368,)
# Score:  75.54347826086956
#        training_set          test_set feature_set feature_type     model_type  \
# 0  neutral_surprise  neutral_surprise     neutral     distance  XGBClassifier
#
#     accuracy
# 0  80.869565
#
# surprise: neutral_surprise-neutral_surprise with surprise using XGBClassifier
# Running test #1/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  73.91304347826086
# Running test #2/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  71.73913043478261
# Running test #3/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  73.91304347826086
# Running test #4/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  67.93478260869566
# Running test #5/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  74.45652173913044
# Running test #6/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  80.97826086956522
# Running test #7/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  78.80434782608695
# Running test #8/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  82.06521739130434
# Running test #9/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  79.8913043478261
# Running test #10/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  81.52173913043478
# Running test #11/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  72.82608695652173
# Running test #12/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  85.86956521739131
# Running test #13/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  75.54347826086956
# Running test #14/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  76.63043478260869
# Running test #15/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  69.56521739130434
# Running test #16/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  72.82608695652173
# Running test #17/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  64.13043478260869
# Running test #18/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  80.97826086956522
# Running test #19/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  80.97826086956522
# Running test #20/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  71.73913043478261
# Running test #21/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  76.63043478260869
# Running test #22/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  80.97826086956522
# Running test #23/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  78.26086956521739
# Running test #24/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  66.30434782608695
# Running test #25/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 12) (368,)
# Score:  70.65217391304348
#        training_set          test_set feature_set feature_type     model_type  \
# 0  neutral_surprise  neutral_surprise     neutral     distance  XGBClassifier
# 1  neutral_surprise  neutral_surprise    surprise     distance  XGBClassifier
#
#     accuracy
# 0  80.869565
# 1  75.565217
#
# surprise: neutral_surprise-neutral_surprise with neutral_surprise using XGBClassifier
# Running test #1/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  84.78260869565217
# Running test #2/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  81.52173913043478
# Running test #3/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  85.86956521739131
# Running test #4/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  80.43478260869566
# Running test #5/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  86.95652173913044
# Running test #6/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  87.5
# Running test #7/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  90.21739130434783
# Running test #8/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  88.58695652173914
# Running test #9/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  90.21739130434783
# Running test #10/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  91.84782608695652
# Running test #11/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  84.78260869565217
# Running test #12/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  94.02173913043478
# Running test #13/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  84.78260869565217
# Running test #14/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  85.32608695652173
# Running test #15/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  84.23913043478261
# Running test #16/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  83.15217391304348
# Running test #17/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  76.08695652173914
# Running test #18/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  89.13043478260869
# Running test #19/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  89.67391304347827
# Running test #20/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  84.78260869565217
# Running test #21/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  85.32608695652173
# Running test #22/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  90.21739130434783
# Running test #23/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  85.86956521739131
# Running test #24/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  74.45652173913044
# Running test #25/25
# Reading subjects for surprise... [no_of_subjects=None]
# (368, 20) (368,)
# Score:  83.15217391304348
#        training_set          test_set       feature_set feature_type  \
# 0  neutral_surprise  neutral_surprise           neutral     distance
# 1  neutral_surprise  neutral_surprise          surprise     distance
# 2  neutral_surprise  neutral_surprise  neutral_surprise     distance
#
#       model_type   accuracy
# 0  XGBClassifier  80.869565
# 1  XGBClassifier  75.565217
# 2  XGBClassifier  85.717391
